# %% [markdown]
# # Lab 3 - CNN Models
#
# You will be graded based on
#
# - Originality of your implementation
# - Result of your implementation
# - In-class Q/A to test your understanding
#
# Note: **DO NOT** add comments in your code

# %% [markdown]
# ## Question 1
# Choose **ONE** of these CNN networks:
# - LeNet-5 (1998)
# - AlexNet (2012)
# - R-CNN (2013)
# - GoogLeNet / Inception (2014)
# - VGGNet (2014)
# - ResNet (2015)
# - U-NET (2015)
# - SSD (2015)
# - DenseNet (2016)
# - Xception (2016)
# - YOLO (2016)
# - MobileNet (2017)
# - EfficientNet (2019)
#
# And implement it for **ONE** Computer Vision task of your choice on **any** dataset:
# - Image Classification
# - Object Detection
# - Semantic Segmentation
# - Instance Segmentation
#
# ![image.png](attachment:2c2e45b9-ac3b-43ce-844e-c5d4e40c3562.png)

# %% [markdown]
# ## Question 2: In-class Q/A
# You will be asked questions based on your CNN Network from `Question 1`
#
# Question examples:
# - What is `Depthwise Separable Convolution blocks` in Xception Network?
# - What is `Residual block` in ResNet Network?
#
# Note:
# - You don't have to write anything for `Question 2`, but you should prepare by reading thoroughly about the architecture of your CNN Network.
# - If you choose a CNN architecture that have multiple version like:
#   - Yolo v1, v2,..v8. I will only ask questions related to the original architecture v1.
#   - R-CNN, Fast R-CNN, Faster R-CNN. I will only ask questions related to the original architecture R-CNN.
# - If you submit after-class, you won't receive a score for this question.
